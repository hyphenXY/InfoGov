# %%
! pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /home/mint/hypenX/InfoGov/.venv/lib/python3.12/site-packages (1.1.1)

# %%
import pymysql
import json
import requests
import jellyfish
from datetime import datetime
import re
import pandas

# %%
df = pandas.read_csv("../7047.csv")

# %%
# df

# %%
timeout = 10
connection = pymysql.connect(
  charset="utf8mb4",
  connect_timeout=timeout,
  cursorclass=pymysql.cursors.DictCursor,
  db="iia_group2",
  host="world-athletics-world-athletics.h.aivencloud.com",
  password="AVNS_q4qfMZEYhnIhreAFwYi",
  read_timeout=timeout,
  port=24936,
  user="avnadmin",
  write_timeout=timeout,
)

# %%
states = []
cursor = connection.cursor()
cursor.execute("select state from States")
x = cursor.fetchall()
cursor.close()

# %%
unique_state_list = [i["state"] for i in x ]

# %%
# x

# %%
def check_similarity(col_name_sql,col_name_api):
    pass

def match_state_name(input_state, unique_states_list):
    # Initialize variables to store the best match and highest score
    best_match = None
    highest_score = 0

    # Iterate through the unique states list and calculate Jaro-Winkler scores
    for state in unique_states_list:
        similarity_score = jellyfish.jaro_winkler_similarity(input_state, state)
        if similarity_score > highest_score:
            highest_score = similarity_score
            best_match = state
        # print(similarity_score, state)

    # Return the best matching state name
    if(highest_score < 0.7):
        return None
    return best_match

def get_start_date(string:str):
    try:
        temp = re.split(r"[(),-]",string)
        date_string = "1 " + temp[1] + " " + temp[-1] 
        date_object = datetime.strptime(date_string, "%d %b %Y").date()
        return date_object
    except:
        return None

def get_end_date(string:str):
    try:
        temp = re.split(r"[(),-]",string)
        date_string = "1 " + temp[2] + " " + str(int(temp[-1]) +1)
        date_object = datetime.strptime(date_string, "%d %b %Y").date()
    except:
        return None
    return date_object

# %%
def get_month(string: str):
    try:
        temp = re.split(r"[(),-]",string)
        
        date_string = "1 " + temp[-2] + " " + str(int(temp[-1]))
        # print(date_string)
        date_object = datetime.strptime(date_string, "%d %B %Y").date()
    except:
        return None
    return date_object

# %%
get_month("December, 2019")
# Out:
# datetime.date(2019, 12, 1)

# %%
get_end_date("Financial Year (Apr - Mar), 2017")
# Out:
# datetime.date(2018, 3, 1)

# %%
df_per_year = df.drop(["State LGD code","Country"],axis=1)

# %%
# df_per_year

# %%
# df_per_year
df_per_month = df.drop(["Year","State LGD code","Country"],axis=1)

# %%
# df_per_month
df_per_year
# Out:
#                                              State  \
# 0                                Jammu And Kashmir
# 1                                Jammu And Kashmir
# 2                                Jammu And Kashmir
# 3                                Jammu And Kashmir
# 4                                Jammu And Kashmir
# ...                                            ...
# 2119  The Dadra And Nagar Haveli And Daman And Diu
# 2120  The Dadra And Nagar Haveli And Daman And Diu
# 2121  The Dadra And Nagar Haveli And Daman And Diu
# 2122  The Dadra And Nagar Haveli And Daman And Diu
# 2123  The Dadra And Nagar Haveli And Daman And Diu
#
#                                  Year            Month  \
# 0     Calendar Year (Jan - Dec), 2017     August, 2017
# 1     Calendar Year (Jan - Dec), 2017  September, 2017
# 2     Calendar Year (Jan - Dec), 2017    October, 2017
# 3     Calendar Year (Jan - Dec), 2017   November, 2017
# 4     Calendar Year (Jan - Dec), 2017   December, 2017
# ...                               ...              ...
# 2119  Calendar Year (Jan - Dec), 2022   February, 2022
# 2120  Calendar Year (Jan - Dec), 2022      March, 2022
# 2121  Calendar Year (Jan - Dec), 2022      April, 2022
# 2122  Calendar Year (Jan - Dec), 2022        May, 2022
# 2123  Calendar Year (Jan - Dec), 2022       June, 2022
#
#       Settlement of Integrated goods and services tax ( IGST )_avg  \
# 0                                             81.591826
# 1                                            139.444544
# 2                                            191.539490
# 3                                            204.687283
# 4                                            182.624872
# ...                                                 ...
# 2119                                          36.365185
# 2120                                          79.902823
# 2121                                          55.222938
# 2122                                          45.330816
# 2123                                         -19.675713
#
#       Settlement of Integrated goods and services tax ( IGST )_max  \
# 0                                             81.591826
# 1                                            139.444544
# 2                                            191.539490
# 3                                            204.687283
# 4                                            182.624872
# ...                                                 ...
# 2119                                          36.365185
# 2120                                          79.902823
# 2121                                          55.222938
# 2122                                          45.330816
# 2123                                         -19.675713
#
#       Settlement of Integrated goods and services tax ( IGST )_min  \
# 0                                             81.591826
# 1                                            139.444544
# 2                                            191.539490
# 3                                            204.687283
# 4                                            182.624872
# ...                                                 ...
# 2119                                          36.365185
# 2120                                          79.902823
# 2121                                          55.222938
# 2122                                          45.330816
# 2123                                         -19.675713
#
#       Settlement of Integrated goods and services tax ( IGST )_sum  \
# 0                                             81.591826
# 1                                            139.444544
# 2                                            191.539490
# 3                                            204.687283
# 4                                            182.624872
# ...                                                 ...
# 2119                                          36.365185
# 2120                                          79.902823
# 2121                                          55.222938
# 2122                                          45.330816
# 2123                                         -19.675713
#
#       Settlement of Integrated goods and services tax ( IGST )_count  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 2119                                                  1
# 2120                                                  1
# 2121                                                  1
# 2122                                                  1
# 2123                                                  1
#
#       Settlement of Integrated goods and services tax ( IGST )_stddev  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2119                                                NaN
# 2120                                                NaN
# 2121                                                NaN
# 2122                                                NaN
# 2123                                                NaN
#
#       Settlement of Integrated goods and services tax ( IGST )_LandAreaWeight  \
# 0                                                81.592
# 1                                               139.445
# 2                                               191.539
# 3                                               204.687
# 4                                               182.625
# ...                                                 ...
# 2119                                             36.365
# 2120                                             79.903
# 2121                                             55.223
# 2122                                             45.331
# 2123                                            -19.676
#
#       Settlement of Integrated goods and services tax ( IGST )_TotalPopulationWeight  \
# 0                                                81.592
# 1                                               139.445
# 2                                               191.539
# 3                                               204.687
# 4                                               182.625
# ...                                                 ...
# 2119                                             36.365
# 2120                                             79.903
# 2121                                             55.223
# 2122                                             45.331
# 2123                                            -19.676
#
#       Settlement of Integrated goods and services tax ( IGST )_NumberOfHouseholdsWeight  \
# 0                                                81.592
# 1                                               139.445
# 2                                               191.539
# 3                                               204.687
# 4                                               182.625
# ...                                                 ...
# 2119                                             36.365
# 2120                                             79.903
# 2121                                             55.223
# 2122                                             45.331
# 2123                                            -19.676
#
#       Settlement of Integrated goods and services tax ( IGST )_TotalPopulationMaleWeight  \
# 0                                                81.592
# 1                                               139.445
# 2                                               191.539
# 3                                               204.687
# 4                                               182.625
# ...                                                 ...
# 2119                                             36.365
# 2120                                             79.903
# 2121                                             55.223
# 2122                                             45.331
# 2123                                            -19.676
#
#       Settlement of Integrated goods and services tax ( IGST )_TotalPopulationFemaleWeight
# 0                                                81.592
# 1                                               139.445
# 2                                               191.539
# 3                                               204.687
# 4                                               182.625
# ...                                                 ...
# 2119                                             36.365
# 2120                                             79.903
# 2121                                             55.223
# 2122                                             45.331
# 2123                                            -19.676
#
# [2124 rows x 14 columns]

# %%
# import numpy as np
df_per_year = df_per_year.groupby(["State","Year"]).mean().reset_index()

# %%
for i in df_per_year.keys():
    x = i.split('_')
    if(len(x) == 2 and x[1] != 'avg'):
        print(df_per_year[i])
        df_per_year = df_per_year.drop([i],axis=1)

# %%
for i in df_per_month.keys():
    x = i.split('_')
    if(len(x) == 2 and x[1] != 'avg'):
        print(df_per_month[i])
        df_per_month = df_per_month.drop([i],axis=1)

# %%
cols
# Out:
# {'regional_rural_banks', 'scheduled_commercial_banks'}

# %%
# df_per_month
# Out:
#                                             State  \
# 0                               Jammu And Kashmir
# 1                               Jammu And Kashmir
# 2                               Jammu And Kashmir
# 3                               Jammu And Kashmir
# 4                               Jammu And Kashmir
# ..                                            ...
# 391  The Dadra And Nagar Haveli And Daman And Diu
# 392  The Dadra And Nagar Haveli And Daman And Diu
# 393  The Dadra And Nagar Haveli And Daman And Diu
# 394  The Dadra And Nagar Haveli And Daman And Diu
# 395  The Dadra And Nagar Haveli And Daman And Diu
#
#      Credit to agriculture by Scheduled Commercial Banks_avg  \
# 0                                          1365.922455
# 1                                          1561.054235
# 2                                          2731.844911
# 3                                          4097.767366
# 4                                          5170.992153
# ..                                                 ...
# 391                                         100.000000
# 392                                         100.000000
# 393                                         100.000000
# 394                                          95.000000
# 395                                         109.000000
#
#      Personal loans by Scheduled Commercial Banks_avg  \
# 0                                         4695.019895
# 1                                         5575.336125
# 2                                         7042.529843
# 3                                         8509.723560
# 4                                        10368.168935
# ..                                                ...
# 391                                        900.000000
# 392                                       1300.000000
# 393                                       1599.000000
# 394                                       1948.000000
# 395                                       2108.000000
#
#      Credit to industry by Scheduled Commercial Banks_avg  \
# 0                                          2836.574520
# 1                                          2934.387434
# 2                                          4010.329494
# 3                                          5086.271553
# 4                                          5868.774869
# ..                                                 ...
# 391                                        1500.000000
# 392                                        1600.000000
# 393                                        1811.000000
# 394                                        2700.000000
# 395                                        3039.000000
#
#      Credit by Scheduled Commercial Banks in India_avg  \
# 0                                         14965.375916
# 1                                         16530.382547
# 2                                         21421.028271
# 3                                         26116.048166
# 4                                         30419.816403
# ..                                                 ...
# 391                                        2316.000000
# 392                                        3000.000000
# 393                                        4199.000000
# 394                                        6458.000000
# 395                                        6066.000000
#
#      Distribution of offices of Scheduled Commercial Banks_avg  \
# 0                                          1018.232440
# 1                                          1171.798715
# 2                                          1334.168154
# 3                                          1501.428237
# 4                                          1598.263023
# ..                                                 ...
# 391                                         105.000000
# 392                                         106.000000
# 393                                         106.000000
# 394                                         110.000000
# 395                                         104.000000
#
#      Deposits of Regional Rural Banks_avg  \
# 0                             1956.258290
# 1                             2249.697033
# 2                             2543.135776
# 3                             2836.574520
# 4                             3032.200349
# ..                                    ...
# 391                                   NaN
# 392                                   NaN
# 393                                   NaN
# 394                                   NaN
# 395                                   NaN
#
#      Credit-Deposit ratio of Scheduled Commercial Banks according to place of utilisation_avg  \
# 0                                            35.700000
# 1                                            34.100000
# 2                                            37.200000
# 3                                            40.400000
# 4                                            42.500000
# ..                                                 ...
# 391                                          38.930589
# 392                                          45.097155
# 393                                          51.927669
# 394                                          37.886949
# 395                                          30.684330
#
#      Credit-Deposit ratio of Regional Rural Banks_avg  \
# 0                                                35.5
# 1                                                38.8
# 2                                                39.6
# 3                                                43.6
# 4                                                45.2
# ..                                                ...
# 391                                               NaN
# 392                                               NaN
# 393                                               NaN
# 394                                               NaN
# 395                                               NaN
#
#      Credit-Deposit ratio of Scheduled Commercial Banks according to place of sanction_avg  \
# 0                                            38.100000
# 1                                            33.800000
# 2                                            36.900000
# 3                                            40.100000
# 4                                            42.200000
# ..                                                 ...
# 391                                          31.112525
# 392                                          36.869261
# 393                                          43.874575
# 394                                          26.175373
# 395                                          20.670932
#
#      Deposits by Scheduled Commercial Banks in India_avg  \
# 0                                         39320.791621
# 1                                         48906.457240
# 2                                         58100.871201
# 3                                         65143.401044
# 4                                         72088.117972
# ..                                                 ...
# 391                                        7882.000000
# 392                                        8500.000000
# 393                                        9049.000000
# 394                                        9979.000000
# 395                                       11586.000000
#
#      Credit of Regional Rural Banks_avg  \
# 0                            684.690401
# 1                            880.316230
# 2                            978.129145
# 3                           1271.567888
# 4                           1369.380803
# ..                                  ...
# 391                                 NaN
# 392                                 NaN
# 393                                 NaN
# 394                                 NaN
# 395                                 NaN
#
#      Number of Branches of Regional Rural Banks_avg
# 0                                        254.313578
# 1                                        257.247965
# 2                                        260.182353
# 3                                        267.029257
# 4                                        268.985515
# ..                                              ...
# 391                                             NaN
# 392                                             NaN
# 393                                             NaN
# 394                                             NaN
# 395                                             NaN
#
# [396 rows x 13 columns]

# %%
dataframe = {}
cols = set()
for i in df_per_year.keys():
    x = i.split('_')[0]
    y = x.split()
    strep = None
    strep2 = x
    for i in range(len(y)):
        if len(re.findall("bank",y[i].lower())) > 0:
            strep = '_'.join([y[i-2],y[i-1],y[i]]).lower()
            strep2 = ' '.join(y[:i-3])
            break
    dataframe[strep2] = []
    if(strep != None):
        cols.add(strep)

dataframe["bank type"] = []
for _, k in df_per_year.iterrows():
    c1 = {}
    for c in cols:
       c1[c] = {}
    c1["Nan"] = {}
    for i in k.keys():
        x = i.split('_')[0]
        y = x.split()
        strep = "Nan"
        strep2 = x
        for j in range(len(y)):
            if len(re.findall("bank",y[j].lower())) > 0:
                strep = '_'.join([y[j-2],y[j-1],y[j]]).lower()
                strep2 = ' '.join(y[:j-3])
                print(i)
                break
        c1[strep][strep2] = k[i]
    print(strep)
    c1[strep]["bank type"] = strep
    print(c1)
    for m in c1.keys():
        if(m == "Nan"):
            continue
        c1[m]['bank type'] = m 
        for itr in dataframe.keys():
            try:
                dataframe[itr].append(c1[m][itr])
            except KeyError:
                try:
                    dataframe[itr].append(c1["Nan"][itr])
                except:
                    dataframe[itr].append(None)

    # break
    
df_per_year = pandas.DataFrame(dataframe)
# Out:
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 684.69, 'Distribution of offices': nan, 'Deposits': 1956.258, 'Credit-Deposit ratio': 35.5, 'Number of Branches': 254.314, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 1365.922, 'Personal loans': 4695.02, 'Credit to industry': 2836.575, 'Credit': 14965.376, 'Distribution of offices': 1018.232, 'Deposits': 39320.792, 'Credit-Deposit ratio': 38.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 880.316, 'Distribution of offices': nan, 'Deposits': 2249.697, 'Credit-Deposit ratio': 38.8, 'Number of Branches': 257.248, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 1561.054, 'Personal loans': 5575.336, 'Credit to industry': 2934.387, 'Credit': 16530.383, 'Distribution of offices': 1171.799, 'Deposits': 48906.457, 'Credit-Deposit ratio': 33.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 978.129, 'Distribution of offices': nan, 'Deposits': 2543.136, 'Credit-Deposit ratio': 39.6, 'Number of Branches': 260.182, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': 2731.845, 'Personal loans': 7042.53, 'Credit to industry': 4010.329, 'Credit': 21421.028, 'Distribution of offices': 1334.168, 'Deposits': 58100.871, 'Credit-Deposit ratio': 36.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1271.568, 'Distribution of offices': nan, 'Deposits': 2836.575, 'Credit-Deposit ratio': 43.6, 'Number of Branches': 267.029, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': 4097.767, 'Personal loans': 8509.724, 'Credit to industry': 5086.272, 'Credit': 26116.048, 'Distribution of offices': 1501.428, 'Deposits': 65143.401, 'Credit-Deposit ratio': 40.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1369.381, 'Distribution of offices': nan, 'Deposits': 3032.2, 'Credit-Deposit ratio': 45.2, 'Number of Branches': 268.986, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': 5170.992, 'Personal loans': 10368.169, 'Credit to industry': 5868.775, 'Credit': 30419.816, 'Distribution of offices': 1598.263, 'Deposits': 72088.118, 'Credit-Deposit ratio': 42.2, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1692.163, 'Distribution of offices': nan, 'Deposits': 3531.046, 'Credit-Deposit ratio': 47.9, 'Number of Branches': 318.87, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': 5366.124, 'Personal loans': 13009.118, 'Credit to industry': 6162.214, 'Credit': 34625.772, 'Distribution of offices': 1668.688, 'Deposits': 78543.77, 'Credit-Deposit ratio': 44.2, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1672.601, 'Distribution of offices': nan, 'Deposits': 3941.86, 'Credit-Deposit ratio': 42.4, 'Number of Branches': 320.826, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': 5463.69, 'Personal loans': 14476.311, 'Credit to industry': 6162.214, 'Credit': 36380.535, 'Distribution of offices': 1702.923, 'Deposits': 91304.443, 'Credit-Deposit ratio': 39.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1956.258, 'Distribution of offices': nan, 'Deposits': 4499.394, 'Credit-Deposit ratio': 43.5, 'Number of Branches': 352.126, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 6146.651, 'Personal loans': 18584.454, 'Credit to industry': 7727.22, 'Credit': 43624.56, 'Distribution of offices': 1744.004, 'Deposits': 101725.431, 'Credit-Deposit ratio': 42.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2264.369, 'Distribution of offices': nan, 'Deposits': 4754.686, 'Credit-Deposit ratio': 47.6, 'Number of Branches': 335.498, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 6725.217, 'Personal loans': 24209.674, 'Credit to industry': 8638.837, 'Credit': 53094.806, 'Distribution of offices': 1789.976, 'Deposits': 115538.571, 'Credit-Deposit ratio': 45.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2626.0, 'Distribution of offices': nan, 'Deposits': 5190.0, 'Credit-Deposit ratio': 50.6, 'Number of Branches': 337.0, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 7240.0, 'Personal loans': 28313.0, 'Credit to industry': 9538.0, 'Credit': 59202.0, 'Distribution of offices': 1767.0, 'Deposits': 128026.0, 'Credit-Deposit ratio': 45.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 3084.0, 'Distribution of offices': nan, 'Deposits': 5668.0, 'Credit-Deposit ratio': 54.4, 'Number of Branches': 345.0, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Jammu And Kashmir', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 9039.0, 'Personal loans': 34569.0, 'Credit to industry': nan, 'Credit': 69908.0, 'Distribution of offices': 1800.0, 'Deposits': 142897.0, 'Credit-Deposit ratio': 48.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'jammu and kashmir', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 700.0, 'Distribution of offices': nan, 'Deposits': 1600.0, 'Credit-Deposit ratio': 42.6, 'Number of Branches': 156.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 2400.0, 'Personal loans': 3900.0, 'Credit to industry': 5800.0, 'Credit': 13500.0, 'Distribution of offices': 1077.0, 'Deposits': 32400.0, 'Credit-Deposit ratio': 41.6, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 800.0, 'Distribution of offices': nan, 'Deposits': 1900.0, 'Credit-Deposit ratio': 42.8, 'Number of Branches': 160.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 2800.0, 'Personal loans': 4100.0, 'Credit to industry': 5700.0, 'Credit': 14800.0, 'Distribution of offices': 1164.0, 'Deposits': 38000.0, 'Credit-Deposit ratio': 38.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 900.0, 'Distribution of offices': nan, 'Deposits': 2100.0, 'Credit-Deposit ratio': 43.4, 'Number of Branches': 187.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': 3300.0, 'Personal loans': 4400.0, 'Credit to industry': 6300.0, 'Credit': 15800.0, 'Distribution of offices': 1264.0, 'Deposits': 45000.0, 'Credit-Deposit ratio': 35.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1000.0, 'Distribution of offices': nan, 'Deposits': 2500.0, 'Credit-Deposit ratio': 39.3, 'Number of Branches': 188.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': 4100.0, 'Personal loans': 5700.0, 'Credit to industry': 5000.0, 'Credit': 18600.0, 'Distribution of offices': 1386.0, 'Deposits': 52000.0, 'Credit-Deposit ratio': 35.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1000.0, 'Distribution of offices': nan, 'Deposits': 3000.0, 'Credit-Deposit ratio': 33.3, 'Number of Branches': 188.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': 4500.0, 'Personal loans': 6000.0, 'Credit to industry': 5300.0, 'Credit': 21100.0, 'Distribution of offices': 1466.0, 'Deposits': 59900.0, 'Credit-Deposit ratio': 35.3, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1170.0, 'Distribution of offices': nan, 'Deposits': 3260.0, 'Credit-Deposit ratio': 35.9, 'Number of Branches': 188.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': 5900.0, 'Personal loans': 6400.0, 'Credit to industry': 4700.0, 'Credit': 21800.0, 'Distribution of offices': 1510.0, 'Deposits': 66300.0, 'Credit-Deposit ratio': 32.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1290.0, 'Distribution of offices': nan, 'Deposits': 3970.0, 'Credit-Deposit ratio': 32.5, 'Number of Branches': 186.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': 5700.0, 'Personal loans': 7900.0, 'Credit to industry': 4400.0, 'Credit': 23339.0, 'Distribution of offices': 1542.0, 'Deposits': 78523.0, 'Credit-Deposit ratio': 29.7, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1400.0, 'Distribution of offices': nan, 'Deposits': 4300.0, 'Credit-Deposit ratio': 32.6, 'Number of Branches': 187.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 5800.0, 'Personal loans': 9500.0, 'Credit to industry': 4600.0, 'Credit': 26400.0, 'Distribution of offices': 1531.0, 'Deposits': 84900.0, 'Credit-Deposit ratio': 31.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1848.0, 'Distribution of offices': nan, 'Deposits': 5098.0, 'Credit-Deposit ratio': 36.3, 'Number of Branches': 269.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 6560.0, 'Personal loans': 11112.0, 'Credit to industry': 4641.0, 'Credit': 30332.0, 'Distribution of offices': 1635.0, 'Deposits': 95529.0, 'Credit-Deposit ratio': 30.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2117.0, 'Distribution of offices': nan, 'Deposits': 5811.0, 'Credit-Deposit ratio': 36.4, 'Number of Branches': 270.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 6525.0, 'Personal loans': 12446.0, 'Credit to industry': 5034.0, 'Credit': 32327.0, 'Distribution of offices': 1652.0, 'Deposits': 103545.0, 'Credit-Deposit ratio': 30.2, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2443.0, 'Distribution of offices': nan, 'Deposits': 6478.0, 'Credit-Deposit ratio': 37.7, 'Number of Branches': 270.0, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Himachal Pradesh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 6879.0, 'Personal loans': 14569.0, 'Credit to industry': 5748.0, 'Credit': 35899.0, 'Distribution of offices': 1683.0, 'Deposits': 112344.0, 'Credit-Deposit ratio': 30.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'himachal pradesh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2100.0, 'Distribution of offices': nan, 'Deposits': 3000.0, 'Credit-Deposit ratio': 69.4, 'Number of Branches': 251.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 26300.0, 'Personal loans': 17900.0, 'Credit to industry': 64400.0, 'Credit': 119000.0, 'Distribution of offices': 3895.0, 'Deposits': 152800.0, 'Credit-Deposit ratio': 77.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 2600.0, 'Distribution of offices': nan, 'Deposits': 3500.0, 'Credit-Deposit ratio': 74.8, 'Number of Branches': 277.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 31200.0, 'Personal loans': 18600.0, 'Credit to industry': 56500.0, 'Credit': 139900.0, 'Distribution of offices': 4346.0, 'Deposits': 172900.0, 'Credit-Deposit ratio': 80.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 3100.0, 'Distribution of offices': nan, 'Deposits': 3900.0, 'Credit-Deposit ratio': 79.9, 'Number of Branches': 300.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': 36700.0, 'Personal loans': 20500.0, 'Credit to industry': 64700.0, 'Credit': 163000.0, 'Distribution of offices': 4854.0, 'Deposits': 199800.0, 'Credit-Deposit ratio': 81.6, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 3700.0, 'Distribution of offices': nan, 'Deposits': 4500.0, 'Credit-Deposit ratio': 82.2, 'Number of Branches': 311.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': 50000.0, 'Personal loans': 26700.0, 'Credit to industry': 66500.0, 'Credit': 182000.0, 'Distribution of offices': 5547.0, 'Deposits': 230000.0, 'Credit-Deposit ratio': 79.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 4500.0, 'Distribution of offices': nan, 'Deposits': 5200.0, 'Credit-Deposit ratio': 86.5, 'Number of Branches': 367.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': 57200.0, 'Personal loans': 28500.0, 'Credit to industry': 70900.0, 'Credit': 196600.0, 'Distribution of offices': 6024.0, 'Deposits': 262000.0, 'Credit-Deposit ratio': 75.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 5240.0, 'Distribution of offices': nan, 'Deposits': 6070.0, 'Credit-Deposit ratio': 86.3, 'Number of Branches': 387.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': 62000.0, 'Personal loans': 31200.0, 'Credit to industry': 67700.0, 'Credit': 202400.0, 'Distribution of offices': 6168.0, 'Deposits': 290100.0, 'Credit-Deposit ratio': 69.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 5850.0, 'Distribution of offices': nan, 'Deposits': 7200.0, 'Credit-Deposit ratio': 81.3, 'Number of Branches': 403.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': 66400.0, 'Personal loans': 35600.0, 'Credit to industry': 65100.0, 'Credit': 228314.0, 'Distribution of offices': 6366.0, 'Deposits': 330956.0, 'Credit-Deposit ratio': 69.0, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 6400.0, 'Distribution of offices': nan, 'Deposits': 7300.0, 'Credit-Deposit ratio': 87.7, 'Number of Branches': 422.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 71100.0, 'Personal loans': 42900.0, 'Credit to industry': 70600.0, 'Credit': 220900.0, 'Distribution of offices': 6474.0, 'Deposits': 347800.0, 'Credit-Deposit ratio': 63.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 6702.0, 'Distribution of offices': nan, 'Deposits': 8156.0, 'Credit-Deposit ratio': 82.2, 'Number of Branches': 421.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 69234.0, 'Personal loans': 48503.0, 'Credit to industry': 61008.0, 'Credit': 236211.0, 'Distribution of offices': 6614.0, 'Deposits': 379577.0, 'Credit-Deposit ratio': 60.3, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 6846.0, 'Distribution of offices': nan, 'Deposits': 8860.0, 'Credit-Deposit ratio': 77.3, 'Number of Branches': 426.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 67532.0, 'Personal loans': 56495.0, 'Credit to industry': 58150.0, 'Credit': 244057.0, 'Distribution of offices': 6735.0, 'Deposits': 410987.0, 'Credit-Deposit ratio': 57.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 7627.0, 'Distribution of offices': nan, 'Deposits': 10133.0, 'Credit-Deposit ratio': 75.3, 'Number of Branches': 429.0, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Punjab', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 66375.0, 'Personal loans': 64554.0, 'Credit to industry': 61886.0, 'Credit': 263532.0, 'Distribution of offices': 6700.0, 'Deposits': 459027.0, 'Credit-Deposit ratio': 55.0, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'punjab', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 6600.0, 'Personal loans': 5000.0, 'Credit to industry': 17500.0, 'Credit': 46200.0, 'Distribution of offices': 337.0, 'Deposits': 38000.0, 'Credit-Deposit ratio': 121.6, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 4400.0, 'Personal loans': 5800.0, 'Credit to industry': 23000.0, 'Credit': 45500.0, 'Distribution of offices': 363.0, 'Deposits': 39400.0, 'Credit-Deposit ratio': 115.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': 4800.0, 'Personal loans': 6000.0, 'Credit to industry': 29600.0, 'Credit': 57900.0, 'Distribution of offices': 383.0, 'Deposits': 45400.0, 'Credit-Deposit ratio': 127.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': 3700.0, 'Personal loans': 6300.0, 'Credit to industry': 33100.0, 'Credit': 57900.0, 'Distribution of offices': 408.0, 'Deposits': 48300.0, 'Credit-Deposit ratio': 120.0, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': 2500.0, 'Personal loans': 7600.0, 'Credit to industry': 36300.0, 'Credit': 58700.0, 'Distribution of offices': 439.0, 'Deposits': 55400.0, 'Credit-Deposit ratio': 105.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': 2500.0, 'Personal loans': 8000.0, 'Credit to industry': 32000.0, 'Credit': 54400.0, 'Distribution of offices': 433.0, 'Deposits': 55600.0, 'Credit-Deposit ratio': 97.8, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': 2100.0, 'Personal loans': 9100.0, 'Credit to industry': 33800.0, 'Credit': 60025.0, 'Distribution of offices': 444.0, 'Deposits': 59618.0, 'Credit-Deposit ratio': 100.7, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 2500.0, 'Personal loans': 10300.0, 'Credit to industry': 34900.0, 'Credit': 69700.0, 'Distribution of offices': 441.0, 'Deposits': 61900.0, 'Credit-Deposit ratio': 112.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 3755.0, 'Personal loans': 11386.0, 'Credit to industry': 36896.0, 'Credit': 77956.0, 'Distribution of offices': 442.0, 'Deposits': 68300.0, 'Credit-Deposit ratio': 111.4, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 2840.0, 'Personal loans': 13326.0, 'Credit to industry': 36404.0, 'Credit': 78002.0, 'Distribution of offices': 454.0, 'Deposits': 72552.0, 'Credit-Deposit ratio': 108.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Chandigarh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 1414.0, 'Personal loans': 14834.0, 'Credit to industry': 30877.0, 'Credit': 80793.0, 'Distribution of offices': 442.0, 'Deposits': 81320.0, 'Credit-Deposit ratio': 96.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'chandigarh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Uttarakhand', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 900.0, 'Distribution of offices': nan, 'Deposits': 1600.0, 'Credit-Deposit ratio': 55.5, 'Number of Branches': 190.0, '': 'bank_type_bank', 'state': 'uttarakhand', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Uttarakhand', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 3600.0, 'Personal loans': 5500.0, 'Credit to industry': 5500.0, 'Credit': 17200.0, 'Distribution of offices': 1278.0, 'Deposits': 48700.0, 'Credit-Deposit ratio': 35.4, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'uttarakhand', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Uttarakhand', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1000.0, 'Distribution of offices': nan, 'Deposits': 1800.0, 'Credit-Deposit ratio': 55.1, 'Number of Branches': 214.0, '': 'bank_type_bank', 'state': 'uttarakhand', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Uttarakhand', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 4200.0, 'Personal loans': 6100.0, 'Credit to industry': 6800.0, 'Credit': 20100.0, 'Distribution of offices': 1450.0, 'Deposits': 56400.0, 'Credit-Deposit ratio': 35.6, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'uttarakhand', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Uttarakhand', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 1200.0, 'Distribution of offices': nan, 'Deposits': 2200.0, 'Credit-Deposit ratio': 57.6, 'Number of Branches': 231.0, '': 'bank_type_bank', 'state': 'uttarakhand', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# ...
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 153.349, 'Personal loans': 415.546, 'Credit to industry': 172.78, 'Credit': 975.44, 'Distribution of offices': 38.996, 'Deposits': 2274.569, 'Credit-Deposit ratio': 42.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 50.631, 'Distribution of offices': nan, 'Deposits': 106.314, 'Credit-Deposit ratio': 47.6, 'Number of Branches': 7.502, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 167.783, 'Personal loans': 541.326, 'Credit to industry': 193.163, 'Credit': 1187.194, 'Distribution of offices': 40.024, 'Deposits': 2583.429, 'Credit-Deposit ratio': 45.5, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 21.0, 'Distribution of offices': nan, 'Deposits': 16.0, 'Credit-Deposit ratio': 128.2, 'Number of Branches': 2.0, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 254.0, 'Personal loans': 1054.0, 'Credit to industry': 128.0, 'Credit': 1812.0, 'Distribution of offices': 68.0, 'Deposits': 4955.0, 'Credit-Deposit ratio': 36.1, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': 22.0, 'Distribution of offices': nan, 'Deposits': 16.0, 'Credit-Deposit ratio': 136.4, 'Number of Branches': 2.0, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'Ladakh', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 269.0, 'Personal loans': 1342.0, 'Credit to industry': 157.0, 'Credit': 2181.0, 'Distribution of offices': 75.0, 'Deposits': 6161.0, 'Credit-Deposit ratio': 34.9, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'ladakh', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2011', 'Credit to agriculture': 0.0, 'Personal loans': 200.0, 'Credit to industry': 1100.0, 'Credit': 800.0, 'Distribution of offices': 58.0, 'Deposits': 2900.0, 'Credit-Deposit ratio': 29.205, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2011, 4, 1), 'end': datetime.date(2012, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2012', 'Credit to agriculture': 0.0, 'Personal loans': 300.0, 'Credit to industry': 1200.0, 'Credit': 900.0, 'Distribution of offices': 74.0, 'Deposits': 3700.0, 'Credit-Deposit ratio': 24.837, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2012, 4, 1), 'end': datetime.date(2013, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2013', 'Credit to agriculture': 0.0, 'Personal loans': 300.0, 'Credit to industry': 1400.0, 'Credit': 1200.0, 'Distribution of offices': 87.0, 'Deposits': 4500.0, 'Credit-Deposit ratio': 29.64, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2013, 4, 1), 'end': datetime.date(2014, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2014', 'Credit to agriculture': 0.0, 'Personal loans': 500.0, 'Credit to industry': 1400.0, 'Credit': 1600.0, 'Distribution of offices': 95.0, 'Deposits': 5300.0, 'Credit-Deposit ratio': 32.967, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2014, 4, 1), 'end': datetime.date(2015, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2015', 'Credit to agriculture': 0.0, 'Personal loans': 500.0, 'Credit to industry': 1000.0, 'Credit': 1800.0, 'Distribution of offices': 100.0, 'Deposits': 6000.0, 'Credit-Deposit ratio': 30.741, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2015, 4, 1), 'end': datetime.date(2016, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2016', 'Credit to agriculture': 0.0, 'Personal loans': 600.0, 'Credit to industry': 1000.0, 'Credit': 1900.0, 'Distribution of offices': 101.0, 'Deposits': 6700.0, 'Credit-Deposit ratio': 30.454, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2016, 4, 1), 'end': datetime.date(2017, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2017', 'Credit to agriculture': 100.0, 'Personal loans': 900.0, 'Credit to industry': 1500.0, 'Credit': 2316.0, 'Distribution of offices': 105.0, 'Deposits': 7882.0, 'Credit-Deposit ratio': 31.113, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2017, 4, 1), 'end': datetime.date(2018, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2018', 'Credit to agriculture': 100.0, 'Personal loans': 1300.0, 'Credit to industry': 1600.0, 'Credit': 3000.0, 'Distribution of offices': 106.0, 'Deposits': 8500.0, 'Credit-Deposit ratio': 36.869, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2018, 4, 1), 'end': datetime.date(2019, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2019', 'Credit to agriculture': 100.0, 'Personal loans': 1599.0, 'Credit to industry': 1811.0, 'Credit': 4199.0, 'Distribution of offices': 106.0, 'Deposits': 9049.0, 'Credit-Deposit ratio': 43.875, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2019, 4, 1), 'end': datetime.date(2020, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2020', 'Credit to agriculture': 95.0, 'Personal loans': 1948.0, 'Credit to industry': 2700.0, 'Credit': 6458.0, 'Distribution of offices': 110.0, 'Deposits': 9979.0, 'Credit-Deposit ratio': 26.175, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2020, 4, 1), 'end': datetime.date(2021, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': nan, 'Personal loans': nan, 'Credit to industry': nan, 'Credit': nan, 'Distribution of offices': nan, 'Deposits': nan, 'Credit-Deposit ratio': nan, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}
# bank type
# bank_type_bank
# {'bank_type_bank': {'': 'bank_type_bank', 'bank type': 'bank_type_bank'}, 'Nan': {'State': 'The Dadra And Nagar Haveli And Daman And Diu', 'Year': 'Financial Year (Apr - Mar), 2021', 'Credit to agriculture': 109.0, 'Personal loans': 2108.0, 'Credit to industry': 3039.0, 'Credit': 6066.0, 'Distribution of offices': 104.0, 'Deposits': 11586.0, 'Credit-Deposit ratio': 20.671, 'Number of Branches': nan, '': 'bank_type_bank', 'state': 'the dadra and nagar haveli and daman and diu', 'start': datetime.date(2021, 4, 1), 'end': datetime.date(2022, 3, 1)}}

# %%
dataframe = {}
cols = set()
for i in df_per_month.keys():
    x = i.split('_')[0]
    y = x.split()
    strep = None
    strep2 = x
    for i in range(len(y)):
        if len(re.findall("bank",y[i].lower())) > 0:
            strep = '_'.join([y[i-2],y[i-1],y[i]]).lower()
            strep2 = ' '.join(y[:i-3])
            break
    dataframe[strep2] = []
    if(strep != None):
        cols.add(strep)

dataframe["bank type"] = []
for _, k in df_per_month.iterrows():
    c1 = {}
    for c in cols:
       c1[c] = {}
    c1["Nan"] = {}
    for i in k.keys():
        x = i.split('_')[0]
        y = x.split()
        strep = "Nan"
        strep2 = x
        for j in range(len(y)):
            if len(re.findall("bank",y[j].lower())) > 0:
                strep = '_'.join([y[j-2],y[j-1],y[j]]).lower()
                strep2 = ' '.join(y[:j-3])
                break
        c1[strep][strep2] = k[i]
    c1[strep]["nanl type"] = strep
    for m in c1.keys():
        if(m == "Nan"):
            continue
        c1[m]['bank type'] = m 
        for itr in dataframe.keys():
            try:
                dataframe[itr].append(c1[m][itr])
            except KeyError:
                try:
                    dataframe[itr].append(c1["Nan"][itr])
                except:
                    dataframe[itr].append(None)

    # break
    
pandas.DataFrame(dataframe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 dataframe = {}
#       2 cols = set()
# ----> 3 for i in df_per_month.keys():
#       4     x = i.split('_')[0]
#       5     y = x.split()
#
# NameError: name 'df_per_month' is not defined

# %%
df_per_year["state"] = df_per_year.apply(lambda x : match_state_name(x["State"],unique_state_list),axis=1)
df_per_year["start_date"] = df_per_year.apply(lambda x : get_start_date(x["Year"]),axis=1)
df_per_year["end_date"] = df_per_year.apply(lambda x : get_end_date(x["Year"]),axis=1)

# %%
df_per_year
# Out:
#                                             State  \
# 0                               Jammu And Kashmir
# 1                               Jammu And Kashmir
# 2                               Jammu And Kashmir
# 3                               Jammu And Kashmir
# 4                               Jammu And Kashmir
# ..                                            ...
# 787  The Dadra And Nagar Haveli And Daman And Diu
# 788  The Dadra And Nagar Haveli And Daman And Diu
# 789  The Dadra And Nagar Haveli And Daman And Diu
# 790  The Dadra And Nagar Haveli And Daman And Diu
# 791  The Dadra And Nagar Haveli And Daman And Diu
#
#                                  Year  Credit to agriculture  Personal loans  \
# 0    Financial Year (Apr - Mar), 2011                    NaN             NaN
# 1    Financial Year (Apr - Mar), 2011               1365.922        4695.020
# 2    Financial Year (Apr - Mar), 2012                    NaN             NaN
# 3    Financial Year (Apr - Mar), 2012               1561.054        5575.336
# 4    Financial Year (Apr - Mar), 2013                    NaN             NaN
# ..                                ...                    ...             ...
# 787  Financial Year (Apr - Mar), 2019                100.000        1599.000
# 788  Financial Year (Apr - Mar), 2020                    NaN             NaN
# 789  Financial Year (Apr - Mar), 2020                 95.000        1948.000
# 790  Financial Year (Apr - Mar), 2021                    NaN             NaN
# 791  Financial Year (Apr - Mar), 2021                109.000        2108.000
#
#      Credit to industry     Credit  Distribution of offices   Deposits  \
# 0                   NaN    684.690                      NaN   1956.258
# 1              2836.575  14965.376                 1018.232  39320.792
# 2                   NaN    880.316                      NaN   2249.697
# 3              2934.387  16530.383                 1171.799  48906.457
# 4                   NaN    978.129                      NaN   2543.136
# ..                  ...        ...                      ...        ...
# 787            1811.000   4199.000                  106.000   9049.000
# 788                 NaN        NaN                      NaN        NaN
# 789            2700.000   6458.000                  110.000   9979.000
# 790                 NaN        NaN                      NaN        NaN
# 791            3039.000   6066.000                  104.000  11586.000
#
#      Credit-Deposit ratio  Number of Branches                  \
# 0                  35.500             254.314  bank_type_bank
# 1                  38.100                 NaN  bank_type_bank
# 2                  38.800             257.248  bank_type_bank
# 3                  33.800                 NaN  bank_type_bank
# 4                  39.600             260.182  bank_type_bank
# ..                    ...                 ...             ...
# 787                43.875                 NaN  bank_type_bank
# 788                   NaN                 NaN  bank_type_bank
# 789                26.175                 NaN  bank_type_bank
# 790                   NaN                 NaN  bank_type_bank
# 791                20.671                 NaN  bank_type_bank
#
#                                             state       start         end  \
# 0                               jammu and kashmir  2011-04-01  2012-03-01
# 1                               jammu and kashmir  2011-04-01  2012-03-01
# 2                               jammu and kashmir  2012-04-01  2013-03-01
# 3                               jammu and kashmir  2012-04-01  2013-03-01
# 4                               jammu and kashmir  2013-04-01  2014-03-01
# ..                                            ...         ...         ...
# 787  the dadra and nagar haveli and daman and diu  2019-04-01  2020-03-01
# 788  the dadra and nagar haveli and daman and diu  2020-04-01  2021-03-01
# 789  the dadra and nagar haveli and daman and diu  2020-04-01  2021-03-01
# 790  the dadra and nagar haveli and daman and diu  2021-04-01  2022-03-01
# 791  the dadra and nagar haveli and daman and diu  2021-04-01  2022-03-01
#
#           bank type  start_date    end_date
# 0    bank_type_bank  2011-04-01  2012-03-01
# 1    bank_type_bank  2011-04-01  2012-03-01
# 2    bank_type_bank  2012-04-01  2013-03-01
# 3    bank_type_bank  2012-04-01  2013-03-01
# 4    bank_type_bank  2013-04-01  2014-03-01
# ..              ...         ...         ...
# 787  bank_type_bank  2019-04-01  2020-03-01
# 788  bank_type_bank  2020-04-01  2021-03-01
# 789  bank_type_bank  2020-04-01  2021-03-01
# 790  bank_type_bank  2021-04-01  2022-03-01
# 791  bank_type_bank  2021-04-01  2022-03-01
#
# [792 rows x 17 columns]

# %%
col_name = []
for i in df_per_year.keys():
    if(i not in  ["State","Year"]):
        print(df_per_year[i])
        df_per_year[i] = df_per_year[i]
        col_name.append(i)
# Out:
# 0           NaN
# 1      1365.922
# 2           NaN
# 3      1561.054
# 4           NaN
#          ...
# 787     100.000
# 788         NaN
# 789      95.000
# 790         NaN
# 791     109.000
# Name: Credit to agriculture, Length: 792, dtype: float64
# 0           NaN
# 1      4695.020
# 2           NaN
# 3      5575.336
# 4           NaN
#          ...
# 787    1599.000
# 788         NaN
# 789    1948.000
# 790         NaN
# 791    2108.000
# Name: Personal loans, Length: 792, dtype: float64
# 0           NaN
# 1      2836.575
# 2           NaN
# 3      2934.387
# 4           NaN
#          ...
# 787    1811.000
# 788         NaN
# 789    2700.000
# 790         NaN
# 791    3039.000
# Name: Credit to industry, Length: 792, dtype: float64
# 0        684.690
# 1      14965.376
# 2        880.316
# 3      16530.383
# 4        978.129
#          ...
# 787     4199.000
# 788          NaN
# 789     6458.000
# 790          NaN
# 791     6066.000
# Name: Credit, Length: 792, dtype: float64
# 0           NaN
# 1      1018.232
# 2           NaN
# 3      1171.799
# 4           NaN
#          ...
# 787     106.000
# 788         NaN
# 789     110.000
# 790         NaN
# 791     104.000
# Name: Distribution of offices, Length: 792, dtype: float64
# 0       1956.258
# 1      39320.792
# 2       2249.697
# 3      48906.457
# 4       2543.136
#          ...
# 787     9049.000
# 788          NaN
# 789     9979.000
# 790          NaN
# 791    11586.000
# Name: Deposits, Length: 792, dtype: float64
# 0      35.500
# 1      38.100
# 2      38.800
# 3      33.800
# 4      39.600
#         ...
# 787    43.875
# 788       NaN
# 789    26.175
# 790       NaN
# 791    20.671
# Name: Credit-Deposit ratio, Length: 792, dtype: float64
# 0      254.314
# 1          NaN
# 2      257.248
# 3          NaN
# 4      260.182
#         ...
# 787        NaN
# 788        NaN
# 789        NaN
# 790        NaN
# 791        NaN
# Name: Number of Branches, Length: 792, dtype: float64
# 0            regional_rural_banks
# 1      scheduled_commercial_banks
# 2            regional_rural_banks
# 3      scheduled_commercial_banks
# 4            regional_rural_banks
#                   ...
# 787    scheduled_commercial_banks
# 788          regional_rural_banks
# 789    scheduled_commercial_banks
# 790          regional_rural_banks
# 791    scheduled_commercial_banks
# Name: , Length: 792, dtype: object
# 0                                 jammu and kashmir
# 1                                 jammu and kashmir
# 2                                 jammu and kashmir
# 3                                 jammu and kashmir
# 4                                 jammu and kashmir
#                            ...
# 787    the dadra and nagar haveli and daman and diu
# 788    the dadra and nagar haveli and daman and diu
# 789    the dadra and nagar haveli and daman and diu
# 790    the dadra and nagar haveli and daman and diu
# 791    the dadra and nagar haveli and daman and diu
# Name: state, Length: 792, dtype: object
# 0      2011-04-01
# 1      2011-04-01
# 2      2012-04-01
# 3      2012-04-01
# 4      2013-04-01
#           ...
# 787    2019-04-01
# 788    2020-04-01
# 789    2020-04-01
# 790    2021-04-01
# 791    2021-04-01
# Name: start, Length: 792, dtype: object
# 0      2012-03-01
# 1      2012-03-01
# 2      2013-03-01
# 3      2013-03-01
# 4      2014-03-01
#           ...
# 787    2020-03-01
# 788    2021-03-01
# 789    2021-03-01
# 790    2022-03-01
# 791    2022-03-01
# Name: end, Length: 792, dtype: object
# 0      bank_type_bank
# 1      bank_type_bank
# 2      bank_type_bank
# 3      bank_type_bank
# 4      bank_type_bank
#             ...
# 787    bank_type_bank
# 788    bank_type_bank
# 789    bank_type_bank
# 790    bank_type_bank
# 791    bank_type_bank
# Name: bank type, Length: 792, dtype: object
# 0      2011-04-01
# 1      2011-04-01
# 2      2012-04-01
# 3      2012-04-01
# 4      2013-04-01
#           ...
# 787    2019-04-01
# 788    2020-04-01
# 789    2020-04-01
# 790    2021-04-01
# 791    2021-04-01
# Name: start_date, Length: 792, dtype: object
# 0      2012-03-01
# 1      2012-03-01
# 2      2013-03-01
# 3      2013-03-01
# 4      2014-03-01
#           ...
# 787    2020-03-01
# 788    2021-03-01
# 789    2021-03-01
# 790    2022-03-01
# 791    2022-03-01
# Name: end_date, Length: 792, dtype: object

# %%
df_per_year[col_name]
# Out:
#      Credit to agriculture  Personal loans  Credit to industry     Credit  \
# 0                      NaN             NaN                 NaN    684.690
# 1                 1365.922        4695.020            2836.575  14965.376
# 2                      NaN             NaN                 NaN    880.316
# 3                 1561.054        5575.336            2934.387  16530.383
# 4                      NaN             NaN                 NaN    978.129
# ..                     ...             ...                 ...        ...
# 787                100.000        1599.000            1811.000   4199.000
# 788                    NaN             NaN                 NaN        NaN
# 789                 95.000        1948.000            2700.000   6458.000
# 790                    NaN             NaN                 NaN        NaN
# 791                109.000        2108.000            3039.000   6066.000
#
#      Distribution of offices   Deposits  Credit-Deposit ratio  \
# 0                        NaN   1956.258                35.500
# 1                   1018.232  39320.792                38.100
# 2                        NaN   2249.697                38.800
# 3                   1171.799  48906.457                33.800
# 4                        NaN   2543.136                39.600
# ..                       ...        ...                   ...
# 787                  106.000   9049.000                43.875
# 788                      NaN        NaN                   NaN
# 789                  110.000   9979.000                26.175
# 790                      NaN        NaN                   NaN
# 791                  104.000  11586.000                20.671
#
#      Number of Branches                              \
# 0               254.314        regional_rural_banks
# 1                   NaN  scheduled_commercial_banks
# 2               257.248        regional_rural_banks
# 3                   NaN  scheduled_commercial_banks
# 4               260.182        regional_rural_banks
# ..                  ...                         ...
# 787                 NaN  scheduled_commercial_banks
# 788                 NaN        regional_rural_banks
# 789                 NaN  scheduled_commercial_banks
# 790                 NaN        regional_rural_banks
# 791                 NaN  scheduled_commercial_banks
#
#                                             state       start         end  \
# 0                               jammu and kashmir  2011-04-01  2012-03-01
# 1                               jammu and kashmir  2011-04-01  2012-03-01
# 2                               jammu and kashmir  2012-04-01  2013-03-01
# 3                               jammu and kashmir  2012-04-01  2013-03-01
# 4                               jammu and kashmir  2013-04-01  2014-03-01
# ..                                            ...         ...         ...
# 787  the dadra and nagar haveli and daman and diu  2019-04-01  2020-03-01
# 788  the dadra and nagar haveli and daman and diu  2020-04-01  2021-03-01
# 789  the dadra and nagar haveli and daman and diu  2020-04-01  2021-03-01
# 790  the dadra and nagar haveli and daman and diu  2021-04-01  2022-03-01
# 791  the dadra and nagar haveli and daman and diu  2021-04-01  2022-03-01
#
#           bank type  start_date    end_date
# 0    bank_type_bank  2011-04-01  2012-03-01
# 1    bank_type_bank  2011-04-01  2012-03-01
# 2    bank_type_bank  2012-04-01  2013-03-01
# 3    bank_type_bank  2012-04-01  2013-03-01
# 4    bank_type_bank  2013-04-01  2014-03-01
# ..              ...         ...         ...
# 787  bank_type_bank  2019-04-01  2020-03-01
# 788  bank_type_bank  2020-04-01  2021-03-01
# 789  bank_type_bank  2020-04-01  2021-03-01
# 790  bank_type_bank  2021-04-01  2022-03-01
# 791  bank_type_bank  2021-04-01  2022-03-01
#
# [792 rows x 15 columns]

# %%
df_per_year[col_name].to_csv("Bank_Data_3.csv")

# %%
df_per_month["state"] = df_per_month.apply(lambda x : match_state_name(x["State"],unique_state_list),axis=1)
df_per_month["date"] = df_per_month.apply(lambda x : get_month(x["Month"]),axis=1)
# df_per_month["registered_payer"] = df_per_month.apply(lambda x : x["Gst ( goods and service tax ) payers registered before due date_avg"] +x["Gst ( goods and service tax ) payers registered after due date_avg"] ,axis=1) 
# df_per_month["eligible_payer"] = df_per_month.apply(lambda x : x["Payer eligible for gst ( goods and service tax ) registration_avg"],axis=1)

# %%
df_per_year_transformed = df_per_year[["state","start_date","end_date","registered_payer","eligible_payer"]]

# %%
col_name = ["state","date"]
for i in df_per_month.keys():
    x = i.split('_')
    if(len(x) == 2 and x[1] == "avg"):
        print(df_per_month[i])
        df_per_month[x[0]] = df_per_month[i]
        col_name.append(x[0])
df_per_month_transformed =  df_per_month[col_name]
# Out:
# 0        81.591826
# 1       139.444544
# 2       191.539490
# 3       204.687283
# 4       182.624872
#            ...
# 2119     36.365185
# 2120     79.902823
# 2121     55.222938
# 2122     45.330816
# 2123    -19.675713
# Name: Settlement of Integrated goods and services tax ( IGST )_avg, Length: 2124, dtype: float64

# %%
df_per_month_transformed.dropna()
# Out:
#                                              state        date  \
# 0                                jammu and kashmir  2017-08-01
# 1                                jammu and kashmir  2017-09-01
# 2                                jammu and kashmir  2017-10-01
# 3                                jammu and kashmir  2017-11-01
# 4                                jammu and kashmir  2017-12-01
# ...                                            ...         ...
# 2119  the dadra and nagar haveli and daman and diu  2022-02-01
# 2120  the dadra and nagar haveli and daman and diu  2022-03-01
# 2121  the dadra and nagar haveli and daman and diu  2022-04-01
# 2122  the dadra and nagar haveli and daman and diu  2022-05-01
# 2123  the dadra and nagar haveli and daman and diu  2022-06-01
#
#       Settlement of Integrated goods and services tax ( IGST )
# 0                                             81.591826
# 1                                            139.444544
# 2                                            191.539490
# 3                                            204.687283
# 4                                            182.624872
# ...                                                 ...
# 2119                                          36.365185
# 2120                                          79.902823
# 2121                                          55.222938
# 2122                                          45.330816
# 2123                                         -19.675713
#
# [2123 rows x 3 columns]

# %%
df_per_year_transformed.dropna()
# Out:
#                            state  start_date    end_date  registered_payer  \
# 0    andaman and nicobar islands  2017-04-01  2018-03-01       2596.500000
# 1    andaman and nicobar islands  2018-04-01  2019-03-01       2871.958333
# 2    andaman and nicobar islands  2019-04-01  2020-03-01       2914.541667
# 3    andaman and nicobar islands  2020-04-01  2021-03-01       3049.166667
# 4    andaman and nicobar islands  2021-04-01  2022-03-01       3207.208333
# ..                           ...         ...         ...               ...
# 211                  west bengal  2018-04-01  2019-03-01     375588.041667
# 212                  west bengal  2019-04-01  2020-03-01     411276.708333
# 213                  west bengal  2020-04-01  2021-03-01     408896.416667
# 214                  west bengal  2021-04-01  2022-03-01     404378.250000
# 215                  west bengal  2022-04-01  2023-03-01     322101.500000
#
#      eligible_payer
# 0       3388.833333
# 1       4107.000000
# 2       3570.041667
# 3       3627.708333
# 4       3562.750000
# ..              ...
# 211   437264.333333
# 212   492672.916667
# 213   511896.625000
# 214   455467.500000
# 215   366632.000000
#
# [215 rows x 5 columns]

# %%
# df_per_year_transformed.to_csv("trans_register_payers_per_year_data.csv")
df_per_month_transformed.to_csv("trans_register_payers_per_month_data_2.csv")
